# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras.layers import Conv2D,Flatten,MaxPooling2D,Input,BatchNormalization,Dropout,Dense
from tensorflow.keras.callbacks import EarlyStopping,TensorBoard ,ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np
from keras.models import Sequential

# %%
import os
from matplotlib import pyplot as plt

import numpy as np

# %%
img_height = 48
img_width = 48
batch_size = 32

# %%
train_data_dir = r'C:\Users\RIYA\Downloads\archive (1)\train'

# %%
validation_data_dir = r'C:\Users\RIYA\Downloads\archive (1)\test'

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  zoom_range=0.3,
                                  horizontal_flip=True,
                                  )
validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(directory=train_data_dir,
                                                   color_mode='grayscale',
                                                   target_size  =(48,48),
                                                   batch_size=64,
                                                   class_mode='categorical',
                                                   shuffle = True)
validation_generator = validation_datagen.flow_from_directory(validation_data_dir,
                                                             color_mode='grayscale',
                                                             target_size = (img_height,img_width),
                                                             batch_size=batch_size,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
model = Sequential()

model.add(Conv2D(32,kernel_size=(3,3),activation = 'relu', input_shape=(48,48,1)))

model.add(Conv2D(64,kernel_size = (3,3),activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.1))

model.add(Conv2D(128,kernel_size = (3,3),activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.1))

model.add(Conv2D(256,kernel_size = (3,3),activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(7,activation = 'softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy', metrics = ['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 46, 46, 32)        320
#
#  conv2d_7 (Conv2D)           (None, 44, 44, 64)        18496
#
#  max_pooling2d_6 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 22, 22, 64)        0
#
#  conv2d_8 (Conv2D)           (None, 20, 20, 128)       73856
#
#  max_pooling2d_7 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  dropout_7 (Dropout)         (None, 10, 10, 128)       0
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 256)         295168
#
#  max_pooling2d_8 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  dropout_8 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten_2 (Flatten)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 512)               2097664
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 2,489,095
# Trainable params: 2,489,095
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(train_generator,
                   steps_per_epoch=100,
                   epochs = 100,
                   validation_data = validation_generator,
                   validation_steps=100)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 75s 730ms/step - loss: 1.8313 - accuracy: 0.2442 - val_loss: 1.8013 - val_accuracy: 0.2503
# Epoch 2/100
# 100/100 [==============================] - 91s 908ms/step - loss: 1.7956 - accuracy: 0.2530 - val_loss: 1.7541 - val_accuracy: 0.2722
# Epoch 3/100
# 100/100 [==============================] - 91s 912ms/step - loss: 1.7562 - accuracy: 0.2763 - val_loss: 1.7035 - val_accuracy: 0.3069
# Epoch 4/100
# 100/100 [==============================] - 91s 913ms/step - loss: 1.7171 - accuracy: 0.3010 - val_loss: 1.6614 - val_accuracy: 0.3450
# Epoch 5/100
# 100/100 [==============================] - 93s 934ms/step - loss: 1.7340 - accuracy: 0.2988 - val_loss: 1.6667 - val_accuracy: 0.3347
# Epoch 6/100
# 100/100 [==============================] - 91s 909ms/step - loss: 1.7131 - accuracy: 0.3046 - val_loss: 1.6440 - val_accuracy: 0.3738
# Epoch 7/100
# Epoch 48/100
# 100/100 [==============================] - 88s 884ms/step - loss: 1.2116 - accuracy: 0.5361 - val_loss: 1.1130 - val_accuracy: 0.5728
# Epoch 49/100
# 100/100 [==============================] - 673s 7s/step - loss: 1.2009 - accuracy: 0.5455 - val_loss: 1.1090 - val_accuracy: 0.5841
# Epoch 50/100
# 100/100 [==============================] - 80s 795ms/step - loss: 1.2206 - accuracy: 0.5342 - val_loss: 1.1047 - val_accuracy: 0.5922
# Epoch 51/100
# 100/100 [==============================] - 75s 753ms/step - loss: 1.1969 - accuracy: 0.5470 - val_loss: 1.0884 - val_accuracy: 0.5866
# Epoch 52/100
# 100/100 [==============================] - 79s 792ms/step - loss: 1.1740 - accuracy: 0.5464 - val_loss: 1.1167 - val_accuracy: 0.5759
# Epoch 53/100
# 100/100 [==============================] - 89s 890ms/step - loss: 1.1868 - accuracy: 0.5512 - val_loss: 1.1084 - val_accuracy: 0.5909
# Epoch 54/100
# 100/100 [==============================] - 87s 871ms/step - loss: 1.2038 - accuracy: 0.5419 - val_loss: 1.0910 - val_accuracy: 0.5831
# Epoch 55/100
# 100/100 [==============================] - 87s 867ms/step - loss: 1.1961 - accuracy: 0.5508 - val_loss: 1.0656 - val_accuracy: 0.5891
# Epoch 56/100
# 100/100 [==============================] - 86s 861ms/step - loss: 1.1814 - accuracy: 0.5530 - val_loss: 1.0954 - val_accuracy: 0.5822
# Epoch 57/100
# 100/100 [==============================] - 89s 893ms/step - loss: 1.1867 - accuracy: 0.5512 - val_loss: 1.0774 - val_accuracy: 0.5978
# Epoch 58/100
# 100/100 [==============================] - 91s 910ms/step - loss: 1.1835 - accuracy: 0.5537 - val_loss: 1.0666 - val_accuracy: 0.6059
# Epoch 59/100
# 100/100 [==============================] - 85s 854ms/step - loss: 1.1656 - accuracy: 0.5581 - val_loss: 1.0918 - val_accuracy: 0.5922
# Epoch 60/100
# 100/100 [==============================] - 85s 847ms/step - loss: 1.1642 - accuracy: 0.5567 - val_loss: 1.0627 - val_accuracy: 0.5987
# Epoch 61/100
# 100/100 [==============================] - 85s 849ms/step - loss: 1.1647 - accuracy: 0.5630 - val_loss: 1.0954 - val_accuracy: 0.5869
# Epoch 62/100
# 100/100 [==============================] - 84s 840ms/step - loss: 1.1430 - accuracy: 0.5652 - val_loss: 1.0705 - val_accuracy: 0.5950
# Epoch 63/100
# 100/100 [==============================] - 85s 850ms/step - loss: 1.1543 - accuracy: 0.5605 - val_loss: 1.0891 - val_accuracy: 0.5900
# Epoch 64/100
# 100/100 [==============================] - 84s 843ms/step - loss: 1.1704 - accuracy: 0.5584 - val_loss: 1.0699 - val_accuracy: 0.5962
# Epoch 65/100
# 100/100 [==============================] - 85s 853ms/step - loss: 1.1632 - accuracy: 0.5567 - val_loss: 1.0792 - val_accuracy: 0.5900
# Epoch 66/100
# 100/100 [==============================] - 87s 865ms/step - loss: 1.1583 - accuracy: 0.5622 - val_loss: 1.0743 - val_accuracy: 0.5947
# Epoch 67/100
# 100/100 [==============================] - 84s 844ms/step - loss: 1.1445 - accuracy: 0.5638 - val_loss: 1.0562 - val_accuracy: 0.6172
# Epoch 68/100
# 100/100 [==============================] - 85s 847ms/step - loss: 1.1618 - accuracy: 0.5597 - val_loss: 1.0577 - val_accuracy: 0.6037
# Epoch 69/100
# 100/100 [==============================] - 84s 843ms/step - loss: 1.1473 - accuracy: 0.5625 - val_loss: 1.0575 - val_accuracy: 0.6050
# Epoch 70/100
# 100/100 [==============================] - 84s 843ms/step - loss: 1.1228 - accuracy: 0.5750 - val_loss: 1.0430 - val_accuracy: 0.6034
# Epoch 71/100
# 100/100 [==============================] - 85s 845ms/step - loss: 1.1581 - accuracy: 0.5669 - val_loss: 1.0485 - val_accuracy: 0.6097
# Epoch 72/100
# 100/100 [==============================] - 84s 841ms/step - loss: 1.1512 - accuracy: 0.5616 - val_loss: 1.0613 - val_accuracy: 0.6069
# Epoch 73/100
# 100/100 [==============================] - 84s 840ms/step - loss: 1.1362 - accuracy: 0.5725 - val_loss: 1.0839 - val_accuracy: 0.5900
# Epoch 74/100
# 100/100 [==============================] - 84s 840ms/step - loss: 1.1387 - accuracy: 0.5719 - val_loss: 1.0690 - val_accuracy: 0.5991
# Epoch 75/100
# 100/100 [==============================] - 85s 851ms/step - loss: 1.1341 - accuracy: 0.5661 - val_loss: 1.0732 - val_accuracy: 0.5994
# Epoch 76/100
# 100/100 [==============================] - 86s 855ms/step - loss: 1.1478 - accuracy: 0.5750 - val_loss: 1.0499 - val_accuracy: 0.5978
# Epoch 77/100
# 100/100 [==============================] - 79s 791ms/step - loss: 1.1475 - accuracy: 0.5634 - val_loss: 1.0316 - val_accuracy: 0.6241
# Epoch 78/100
# 100/100 [==============================] - 87s 865ms/step - loss: 1.1265 - accuracy: 0.5698 - val_loss: 1.0676 - val_accuracy: 0.5975
# Epoch 79/100
# 100/100 [==============================] - 86s 857ms/step - loss: 1.1247 - accuracy: 0.5748 - val_loss: 1.0434 - val_accuracy: 0.6187
# Epoch 80/100
# 100/100 [==============================] - 87s 871ms/step - loss: 1.1269 - accuracy: 0.5667 - val_loss: 1.0085 - val_accuracy: 0.6263
# Epoch 81/100
# 100/100 [==============================] - 88s 881ms/step - loss: 1.1232 - accuracy: 0.5757 - val_loss: 1.0331 - val_accuracy: 0.6131
# Epoch 82/100
# 100/100 [==============================] - 86s 864ms/step - loss: 1.1485 - accuracy: 0.5636 - val_loss: 1.0436 - val_accuracy: 0.6094
# Epoch 83/100
# 100/100 [==============================] - 87s 865ms/step - loss: 1.1289 - accuracy: 0.5684 - val_loss: 1.0446 - val_accuracy: 0.6003
# Epoch 84/100
# 100/100 [==============================] - 85s 851ms/step - loss: 1.1332 - accuracy: 0.5750 - val_loss: 1.0363 - val_accuracy: 0.6056
# Epoch 85/100
# 100/100 [==============================] - 85s 848ms/step - loss: 1.1418 - accuracy: 0.5659 - val_loss: 1.0281 - val_accuracy: 0.6153
# Epoch 86/100
# 100/100 [==============================] - 87s 872ms/step - loss: 1.1076 - accuracy: 0.5792 - val_loss: 1.0300 - val_accuracy: 0.6159
# Epoch 87/100
# 100/100 [==============================] - 86s 858ms/step - loss: 1.1062 - accuracy: 0.5789 - val_loss: 1.0655 - val_accuracy: 0.5962
# Epoch 88/100
# 100/100 [==============================] - 84s 844ms/step - loss: 1.1204 - accuracy: 0.5790 - val_loss: 1.0571 - val_accuracy: 0.6009
# Epoch 89/100
# 100/100 [==============================] - 84s 840ms/step - loss: 1.1117 - accuracy: 0.5820 - val_loss: 1.0623 - val_accuracy: 0.6037
# Epoch 90/100
# 100/100 [==============================] - 84s 845ms/step - loss: 1.1232 - accuracy: 0.5744 - val_loss: 1.0379 - val_accuracy: 0.6137
# Epoch 91/100
# 100/100 [==============================] - 84s 844ms/step - loss: 1.1197 - accuracy: 0.5806 - val_loss: 1.0708 - val_accuracy: 0.6047
# Epoch 92/100
# 100/100 [==============================] - 84s 843ms/step - loss: 1.1196 - accuracy: 0.5870 - val_loss: 1.0229 - val_accuracy: 0.6256
# Epoch 93/100
# 100/100 [==============================] - 84s 840ms/step - loss: 1.0959 - accuracy: 0.5834 - val_loss: 1.0346 - val_accuracy: 0.6209
# Epoch 94/100
# 100/100 [==============================] - 85s 846ms/step - loss: 1.1133 - accuracy: 0.5788 - val_loss: 1.0138 - val_accuracy: 0.6222
# Epoch 95/100
# 100/100 [==============================] - 85s 847ms/step - loss: 1.1056 - accuracy: 0.5819 - val_loss: 1.0363 - val_accuracy: 0.6066
# Epoch 96/100
# 100/100 [==============================] - 84s 842ms/step - loss: 1.1008 - accuracy: 0.5823 - val_loss: 1.0109 - val_accuracy: 0.6216
# Epoch 97/100
# 100/100 [==============================] - 88s 881ms/step - loss: 1.1113 - accuracy: 0.5803 - val_loss: 1.0214 - val_accuracy: 0.6128
# Epoch 98/100
# 100/100 [==============================] - 86s 860ms/step - loss: 1.1245 - accuracy: 0.5732 - val_loss: 1.0442 - val_accuracy: 0.6200
# Epoch 99/100
# 100/100 [==============================] - 86s 861ms/step - loss: 1.0962 - accuracy: 0.5789 - val_loss: 1.0294 - val_accuracy: 0.6028
# Epoch 100/100
# 100/100 [==============================] - 86s 856ms/step - loss: 1.1008 - accuracy: 0.5830 - val_loss: 1.0355 - val_accuracy: 0.6259

# %%
model.save('facialemotion.h5')

# %%
loss  = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label = 'Training_loss')
plt.plot(epochs,val_loss,'r',label = 'Validation_loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']

# %%
val_acc = history.history['val_accuracy']

# %%
plt.plot(epochs,acc,'y',label = 'Training acc')
plt.plot(epochs, val_acc,'r',label = 'Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(epochs,acc,'y',label = 'Training acc')
plt.plot(epochs, val_acc,'r',label = 'Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from keras.models import load_model

# %%
my_model = load_model('facialemotion.h5',compile = False)

# %%
from sklearn import metrics

# %%
test_img, test_lbl = validation_generator.__next__()
predictions = my_model.predict(test_img)

predictions = np.argmax(predictions,axis=1)
test_labels = np.argmax(test_lbl,axis = 1)
# Out:
# 1/1 [==============================] - 1s 622ms/step

# %%
print("Accuracy = " , metrics.accuracy_score(test_labels,predictions))
# Out:
# Accuracy =  0.6875

# %%
import seaborn as sns 
from sklearn.metrics import confusion_matrix

# Get the true labels and predicted labels for the validation set
validation_labels = validation_generator.classes
validation_pred_probs = model.predict(validation_generator)
validation_pred_labels = np.argmax(validation_pred_probs, axis=1)

# Compute the confusion matrix
confusion_mtx = confusion_matrix(validation_labels, validation_pred_labels)
class_names = list(train_generator.class_indices.keys())
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu', 
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 225/225 [==============================] - 16s 72ms/step
